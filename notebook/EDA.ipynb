# %%
import importlib, src.fetch as sf
importlib.reload(sf)
from src.fetch import download_history_tidy

# %%
from src.transform import compute_returns, compute_volatility
from src.metrics import price_lines, cumulative_return_lines, volatility_line

long_df = download_history_tidy(["AAPL","MSFT","NVDA"], period="6mo", interval="1d")
long_df = compute_returns(long_df)
long_df = compute_volatility(long_df, window=20)

fig1 = price_lines(long_df, ["AAPL","MSFT","NVDA"]); fig1.show()
fig2 = cumulative_return_lines(long_df, ["AAPL","MSFT","NVDA"]); fig2.show()
fig3 = volatility_line(long_df, "AAPL", window=20); fig3.show()
